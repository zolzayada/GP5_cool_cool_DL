# %% [markdown]
# # Современные методы анализа данных и машинного обучения, БИ
#
# ## НИУ ВШЭ, 2025-26 учебный год

# %% [markdown]
# ## Групповой проект №5. Deep Learning

# %% [markdown]
# ## Общая информация

# %% [markdown]
# __Дата выдачи:__ 25.05.2026
#
# __Дедлайн по записи в таблицу:__ 4:00 03.06.2026
#
# __Дедлайн по загрузке работ:__ 4:00 15.06.2026
#
# __Защита проекта:__ ~

# %% [markdown]
# ## Формат выполнения

# %% [markdown]
# Групповой проект представляет собой творческое инициативное групповое задание, которое выполняется студентами в командах от 3 до 6 человек. В то же время следует помнить, что чем больше в команде людей, тем выше предъявляются требования в целом к команде, а также к выполняемому ею проекту. Команды разрешается формировать из студентов разных групп.
#
# При оценивании результатов выполнения проекта командой в обязательном порядке проверяется и учитывается в оценке вклад **каждого участника** в общую работу команды. Вследствие этого крайне важно ответственно подойти к выбору сокомандников, распределению обязанностей внутри команды, а также пресечению наличия "мертвых душ" в команде.
#
# При необходимости команда большинством голосов имеет право исключить человека из команды **до загрузки работ** в систему [Anytask](https://anytask.org/), сообщив об этом преподавателю, в случае если такой человек никак не проявлялся в ходе выполнения проекта и являлся как раз таки той самой "мертвой душой". Помните про эту возможность, поскольку наличие "мертвых душ" может негативно повлиять на качество и оценку для всего проекта и, как следствие, в целом для всей команды!
#
# Запись составов команд осуществляется по ссылке в таблице:
#
# https://docs.google.com/spreadsheets/d/16IB8mURLGKoipq0Jld6wOGPMpJbRQ8GCkSZKbIP-XYA/edit?usp=sharing

# %% [markdown]
# ## Отправка материалов группового проекта

# %% [markdown]
# Во избежание использования при выполнении группового проекта генеративных моделей (ChatGPT и так далее) за рамками справочной и образовательной информации (то есть, например, для автоматической генерации кода по одному из этапов) **одному из участников команды** необходимо предварительно загрузить работу в систему [Anytask](https://anytask.org/). Наличие сгенерированного кода или любого другого случая "несанкционированного" использования нейросетей будет считаться плагиатом, и такой проект будет оценен в 0 баллов для всех участников. При отсутствии своевременно загруженных файлов с проектом команде также выставляется 0 за проект.
#
# *Примечание: презентацию проекта загружать необязательно, важно отправить содержательные файлы с кодом и ссылку на репозиторий GitHub.*

# %% [markdown]
# ## Оценивание и штрафы

# %% [markdown]
# Групповой проект оценивается исходя из устной защиты (презентации) командой выполненного ими проекта перед комиссией. Комиссия составляется из преподавателей курса, ассистентов курса, а также приглашенных экспертов из индустрии.
#
# В рамках каждой защиты комиссия выставляет два типа оценок.
#
# Первая оценка — это оценка для всего проекта в целом. Она ставится комиссией, исходя из глубины проработки командой предметной области, сложности применяемых в проекте инструментов, а также прочих аспектов, связанных с содержанием выполняемого в проекте ТЗ. При выставлении этой оценки комиссия ориентируется на критерии, более подробно представленные ниже в разделе "Критерии оценки проекта".
#
# Вторая оценка — это индивидуальная оценка каждого участника команды. Именно эта оценка выставляется впоследствии в ведомость. Индивидуальная оценка участника команды определяется комиссией, исходя из того, насколько участник ориентируется в выполненном командой проекте, как он отвечает на адресованные персонально ему вопросы комиссии, насколько в принципе прослеживается его роль в проекте, а также исходя из других аспектов, связанных с участием конкретного человека в деятельности команды. Индивидуальная оценка не может превосходить оценку команды за проект в целом (первую оценку), однако, в случае когда участник спокойно и корректно отвечает на все адресованные ему вопросы, свободно ориентируется в материале и содержании выполненного проекта, а также когда его роль в работе команды не вызывает сомнений, — в таком случае, индивидуальная оценка участника становится равной оценке для всего проекта (т.е. в идеальном случае — вторая оценка равна первой оценке). Кроме того, в исключительных случаях, при демонстрации участником на защите превосходящих ожидания уровней понимания, участия и вовлечения в рамках проекта, комиссия может своим решением повысить индивидуальную оценку для этого участника на 0,5 или 1 балл относительно общей оценки за проект (первой оценки).
#
# Во избежание субъективности и/или предвзятости оценки тех или иных членов комиссии в отношении тех или иных команд, а также каких-либо иных проявлений неравных условий — распределение команд между комиссиями осуществляется абсолютно рандомно с использованием средств библиотеки Numpy :)) — в качестве рэндом сида выступает дата, в которую производится распределение, например, `np.random.seed(25052026)`.
#
# Обратите, пожалуйста, внимание на то, что бОльшая часть комиссий осуществляет приём проектов в очной форме, однако могут присутствовать и 1-2 комиссии, которые будут работать дистанционно с использованием средств видеосвязи. В случае попадания команды путем случайного распределения в комиссию, работающую в очной форме, *не допускается* какое-либо изменение формата проведения для команды на онлайн-режим, равно как и любые другие перемещения команд между комиссиями (смены комиссий), для сохранения честности и непредвзятости случайного распределения.
#
# Явка студента на защиту проекта является обязательной; вклад студента без его присутствия не оценивается и автоматически является равным нулю. Для дистанционных комиссий дополнительным требованием является обязательное наличие включенной камеры в течение всего времени нахождения в конференции

# %% [markdown]
# ## Описание задания

# %% [markdown]
# В современной бизнес-индустрии использование глубинного обучения приобретает критическое значение. Компании активно внедряют нейронные сети для решения самых разных задач: от анализа структурированных табличных данных до работы с изображениями и текстами. Это позволяет бизнесу принимать более обоснованные решения и оперативно реагировать на изменения рынка.
#
# В данном проекте вы на реальных данных попрактикуетесь в построении и сравнении нейросетевых архитектур для решения двух бизнес-задач разной природы. Первая задача будет связана с табличными данными и решается с помощью полносвязных нейронных сетей. Вторая - с неструктурированными данными: изображениями или текстами, - и решается с помощью более сложных архитектур глубинного обучения. Помимо этого, вы получите опыт организации работы над ML-проектом так, как это принято в индустрии: с версионированием кода, воспроизводимыми экспериментами и сохранением всех артефактов.
#
# Принципиально важно, что обе бизнес-задачи должны быть **содержательно связаны между собой** и **относиться к одной и той же компании или платформе** — таким образом, чтобы вместе они образовывали единое и логически целостное решение для выбранного бизнес-контекста. Проект, в котором две задачи решаются для разных компаний или никак не связаны между собой, оценивается в **0 баллов** для всех участников команды.

# %% [markdown]
# ### Этапы проекта

# %% [markdown]
# Ниже вашему вниманию предлагаются примерные этапы реализации проекта:
#
# - Выбор компании и/или платформы;
# - Формулировка двух связанных бизнес-задач, которые могла бы хотеть решить компания/платформа на основе данных: одна на табличных данных, другая на неструктурированных (изображения или текст);
# - Обоснование сформулированных бизнес-задач и описание того, как предлагаемое решение вписывается в бизнес-процессы компании;
# - Получение необходимых данных путём поиска открытых источников/датасетов, парсинга/работы с API;
# - Формулировка задач в терминах глубинного обучения для решения поставленных бизнес-задач;
# - Выбор и обоснование архитектур нейронных сетей для каждой из задач;
# - Первичная обработка данных;
# - Построение, обучение и сравнение нейросетевых архитектур с обязательным логированием экспериментов;
# - Получение и агрегация результатов, финальные выводы.

# %% [markdown]
# ### Требования к проекту

# %% [markdown]
# В качестве результата выполнения группового проекта ваша команда должна получить презентацию и защитить её перед комиссией, а также предоставить ссылку на репозиторий GitHub с кодом.
#
# Оформление презентации остаётся полностью на ваше усмотрение, но помните, что результат должен быть релевантен для демонстрации бизнес-заказчику — комиссию, принимающую вашу работу, правильнее всего воспринимать именно в таком качестве. Например, вставлять в презентацию строчки кода или злоупотреблять скринами блокнота не рекомендуется.
#
# С точки зрения концепции выполнения проекта, вам необходимо принять на себя роль дата-инженеров: продумать идеологию получения и извлечения данных; дата-аналитиков: соотнести бизнес-задачу с формулировками на языке данных; и главное, безусловно, — дата-сайентистов: реализовать поставленные задачи с помощью методов глубинного обучения и извлечь полезные инсайты из проделанной работы. А в конце, конечно, презентовать всю эту красоту в понятном виде потенциальному заказчику.
#
# Разумеется, чем сложнее и чем нетривиальнее будет ваша задача, а также чем глубже и чем осмысленнее будут выводы, извлечённые в рамках этой задачи, — тем выше окажется качество вашего проекта и тем выше он будет оценён!

# %% [markdown]
# ### Полезные замечания и советы

# %% [markdown]
# - Графики и визуализации — это очень хорошо — все любят графики
# - Следите за тем, чтобы все графики на слайдах можно было прочитать даже без ваших комментариев
# - Не нужно делать просто текстовые слайды
# - Стройте свой проект исходя из того, что ваша цель — представить полезную информацию для бизнеса
# - Любой хороший Data Scientist должен уметь работать в команде, поэтому распределение ваших усилий в проекте остается за вами

# %% [markdown]
# ## Критерии оценки проекта

# %% [markdown]
# Оценка за групповой проект в целом — то есть первая из двух оценок — выставляется по 10-балльной шкале, исходя из 5 критериев. Также комиссия на своё усмотрение может добавить (но не снизить) некоторое количество бонусных баллов за рамками данных критериев.
#
# Каждый из критериев будет перечислен и рассмотрен ниже.

# %% [markdown]
# ### Критерий 1. Выбор задач и бизнес-обоснование (до 2 баллов)
#
# Данный критерий оценивает, насколько обоснованными и осмысленными и **содержательно связанными** получились две решаемые в проекте бизнес-задачи; насколько полно был осуществлён переход от бизнес-задач к задачам глубинного обучения (насколько в реальности постановка задач соответствует исходной постановке задачи с точки зрения интересов компании); а также насколько корректными, объёмными и прикладными для бизнеса получились выявленные в ходе исследования инсайты.
#
# По данному критерию можно получить **максимальный балл** только при условии, что в презентации представлена схема, иллюстрирующая, как предлагаемое решение вписывается в бизнес-процессы компании: откуда поступают данные, каким образом они обрабатываются, как модель генерирует предсказания и каким образом эти предсказания используются для принятия бизнес-решений. Строгая нотация не обязательна — важна логика и понятность схемы для стороннего наблюдателя.

# %% [markdown]
# ### Критерий 2. Инструменты извлечения и обработки данных (до 1,5 баллов)
#
# Данный критерий оценивает техническую реализацию процесса сбора данных ручным и автоматизированным образом, использованные средства предобработки, подготовки данных и EDA. В рамках этого критерия будет рассматриваться спектр различных технических инструментов, внедрённых в проект; корректность, эффективность и правильность их применения; а также сложность и новизна алгоритмов, подходов и библиотек, применяемых к данным.

# %% [markdown]
# ### Критерий 3. Глубинное обучение на табличных данных (до 2 баллов)
#
# Данный критерий оценивает применение полносвязных нейронных сетей для решения бизнес-задачи на табличных данных. В рамках этого критерия будет рассматриваться корректность постановки задачи, осмысленность выбора архитектуры, качество предобработки данных, а также глубина сравнительного анализа различных конфигураций сети.
#
# *__Важно:__ в случае **оценки 0** за этот критерий оценка за весь проект становится равна оценке за этот критерий.*
#
# *По данному критерию можно получить **отличное от нуля количество баллов** только при условии корректного применения полносвязной нейронной сети для решения поставленной задачи на табличных данных.*
#
# *По данному критерию можно получить **1 балл и выше** только при условии осуществления сравнительного анализа различных конфигураций и сложности архитектуры: должно быть рассмотрено не менее трёх вариантов, значимо отличающихся друг от друга — например, по глубине сети, размеру скрытых слоёв, функциям активации, наличию регуляризации. Использование каждой конфигурации, как и подбор гиперпараметров, должны быть подробно описаны и обоснованы; в рамках сравнения должны быть получены и сформулированы явные, значимые выводы о том, как изменение архитектуры влияет на качество решения задачи.*
#
# *По данному критерию можно получить **максимальный балл в 2 балла** только при условии корректного и обоснованного применения архитектурных решений или подходов, не рассматривавшихся в рамках соответствующих лекций и семинаров. Кроме того, **максимальный балл в 2 балла** по данному критерию недостижим без логирования экспериментов в соответствии с требованиями **Критерия 5**. При этом ожидается, что каждая из сравниваемых конфигураций залогирована отдельным запуском с сохранением параметров архитектуры и обучения, метрик качества, а также артефакта обученной модели, позволяющего воспроизвести её предсказания без повторного обучения.*

# %% [markdown]
# ### Критерий 4. Глубинное обучение на неструктурированных данных  (до 3 баллов)
#
# Данный критерий оценивает применение методов глубинного обучения для решения бизнес-задачи на неструктурированных данных: изображениях или текстах. В рамках этого критерия будет рассматриваться спектр различных технических инструментов, внедрённых в проект; корректность, эффективность и правильность их применения; а также сложность и новизна алгоритмов, подходов и библиотек, применяемых к данным. Кроме того, будет оценен сравнительный анализ архитектур нейронных сетей, использованных в решении.
#
# *__Важно:__ в случае **оценки 0** за этот критерий оценка за весь проект становится равна оценке за этот критерий.*
#
# *По данному критерию можно получить **отличное от нуля количество баллов** только при условии использования в проекте сверточных нейронных сетей, рекуррентных нейронных сетей или же более сложных архитектур глубоких нейронных сетей.*
#
# *По данному критерию можно получить **2 балла** только при условии осуществления сравнительного анализа эффективности различных архитектур нейронных сетей внутри вашего проекта на одних и тех же данных. Самих архитектур должно быть не менее трёх; они должны значимо и осмысленно друг от друга отличаться; их использование, как и настройка гиперпараметров, должны быть подробно описаны и обоснованы. Кроме того, в рамках сравнительного анализа должны быть получены и сформулированы явные, значимые выводы о сравнительной эффективности той или иной архитектуры.*
#
# *По данному критерию можно получить **максимальный балл в 3 балла** только при условии корректного и обоснованного применения инструментов/подходов/библиотек для построения моделей, не рассматривавшихся в рамках соответствующих лекций и семинаров. Кроме того, **максимальный балл в 3 балла** по данному критерию недостижим без логирования экспериментов в соответствии с требованиями **Критерия 5**. При этом ожидается, что каждая из сравниваемых архитектур залогирована отдельным запуском с сохранением параметров архитектуры и обучения, метрик качества в разрезе эпох, а также артефакта обученной модели, позволяющего воспроизвести её предсказания без повторного обучения.*

# %% [markdown]
# ### Критерий 5. Инструменты промышленной разработки (до 1,5 баллов)
#
# Данный критерий оценивает, насколько грамотно и профессионально команда организовала процесс совместной разработки и обеспечила воспроизводимость своих экспериментов. В рамках этого критерия рассматриваются две составляющие: оформление репозитория GitHub и логирование экспериментов.
#
# *По данному критерию можно получить **0,5 балла** при выполнении всех следующих требований к репозиторию GitHub:*
#
# - наличие файла `README.md` с описанием проекта, используемых данных и структуры репозитория — после прочтения этого файла у стороннего человека не должно остаться вопросов о том, что делает проект и как в нём разобраться;
# - наличие файла `.gitignore`;
# - осмысленная структура репозитория: код организован по директориям, понятно, где лежат данные, где модели, где ноутбуки;
# - коммиты делаются осмысленно и регулярно по ходу работы над проектом, с понятными комментариями — по истории репозитория должно быть видно, что команда работала совместно на протяжении всего времени, а не залила всё в одном коммите накануне дедлайна.
#
# *По данному критерию можно получить **1 балл** при дополнительном выполнении следующего условия: все эксперименты с моделями — как на табличных, так и на неструктурированных данных — залогированы с использованием специализированного инструмента логирования экспериментов (например, MLflow, Weights & Biases, ClearML, DagsHub или аналогичного). Каждый эксперимент должен быть зафиксирован отдельным запуском и содержать: параметры модели и обучения, метрики качества — для табличных задач в целом по выборке, для задач на неструктурированных данных дополнительно в разрезе эпох, — а также артефакт обученной модели, позволяющий воспроизвести её предсказания без повторного обучения. Хранение файлов моделей исключительно напрямую в репозитории без привязки к системе логирования не засчитывается.*
#
# *По данному критерию можно получить **1,5 балла** при дополнительном выполнении следующего условия: в системе логирования сохранены также данные, использованные при обучении и валидации моделей, — таким образом, чтобы любой эксперимент можно было полностью воспроизвести, имея доступ только к системе логирования, без необходимости искать данные отдельно.*

# %% [markdown]
# ### часть2 с картиночками

# %%
import torchvision
import os
import wandb # для логирования

import numpy as np
import random
from tqdm import *

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim # для оптимизаторов
from torchvision import datasets # для данных
import torchvision.transforms as transforms # для преобразований тензоров

import matplotlib.pyplot as plt

# %%
# !unzip -q data3a-2.zip -d data3a

INPUT_DIR = 'data3a/data3a-2'

dataset = {ds: torchvision.datasets.ImageFolder(root=os.path.join(INPUT_DIR, ds))
    for ds in ['training', 'validation']
}

dataset_size = {ds: len(dataset[ds]) for ds in ['training', 'validation']}
dataset_classes = dataset['training'].classes

print('classes:', dataset_classes,'\nsize:', dataset_size)
# Out:
# classes: ['01-minor', '02-moderate', '03-severe']
# size: {'training': 1383, 'validation': 248}

# %%
def seed_everything(seed):
    random.seed(seed) # фиксируем генератор случайных чисел
    os.environ['PYTHONHASHSEED'] = str(seed) # фиксируем заполнения хешей
    np.random.seed(seed) # фиксируем генератор случайных чисел numpy
    torch.manual_seed(seed) # фиксируем генератор случайных чисел pytorch
    torch.cuda.manual_seed(seed) # фиксируем генератор случайных чисел для GPU
    #torch.backends.cudnn.deterministic = True # выбираем только детерминированные алгоритмы (для сверток)
    #torch.backends.cudnn.benchmark = False # фиксируем алгоритм вычисления сверток

# %%
class CFG:

# Задаем параметры нашего эксперимента

  api = "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"# вписать свой API Wandb
  project = "GP_5_cool"# вписать название эксперимента, который предварительно надо создать в Wandb
  entity = "alenazya06-hse-university"# ввести свой логин
  num_epochs = 10 # количество эпох
  train_batch_size = 16 # размер батча обучающей выборки
  test_batch_size = 32 # размер батча валид. выборки
  num_workers = 2 # количество активных процессов на загрузку данных
  lr = 0.001 # learning_rate
  seed = 2022 # для функции воспроизводимости
  wandb = False # флаг использования Wandb

# %%
# определим несколько констант

INPUT_DIR = 'data3a/data3a-2'
# поканальные значения среднего и стандартного отклонения для ImageNet
IMAGENET_MEAN = np.array([0.485, 0.456, 0.406])
IMAGENET_STD = np.array([0.229, 0.224, 0.225])
DEVICE = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
# выполним трансформации
data_transforms = {
    'training': transforms.Compose([
        transforms.Resize(256), # меняем размер
        transforms.RandomCrop(244), # вырезаем случайную область указанного размера
        transforms.RandomHorizontalFlip(), # зеркальное отражение по горизонтали
        transforms.ToTensor(),
        transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD) # нормализация
    ]),
    'validation': transforms.Compose([ # на валидации нельзя делать никаких преобразований (кроме изменения размера),
                               # ведь мы должны проверить модель на реальных картинках
        transforms.Resize(256),
        transforms.CenterCrop(244),
        transforms.ToTensor(),
        transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD)
    ]),
}

# %%
dataset = {ds: torchvision.datasets.ImageFolder(
    root=os.path.join(INPUT_DIR, ds),
    transform=data_transforms[ds]
) for ds in ['training', 'validation']}

dataset_size = {ds: len(dataset[ds]) for ds in ['training', 'validation']}
dataset_classes = dataset['training'].classes
print('classes:', dataset_classes, '\nsize:', dataset_size)

# загружаем данные
dataloader = {
    'training': torch.utils.data.DataLoader(
        dataset=dataset['training'], batch_size=CFG.train_batch_size, shuffle=True, num_workers=CFG.num_workers
    ),
    'validation': torch.utils.data.DataLoader(
        dataset=dataset['validation'], batch_size=CFG.test_batch_size, shuffle=False, num_workers=CFG.num_workers
    ),
}
# Out:
# classes: ['01-minor', '02-moderate', '03-severe']
# size: {'training': 1383, 'validation': 248}

# %%
class CIFAR_Net(torch.nn.Module):
    def __init__(self):
        super(CIFAR_Net, self).__init__()

        self.conv1 = torch.nn.Conv2d(3, 16, 3, padding=1)
        self.bn1   = torch.nn.BatchNorm2d(16)
        self.act1  = torch.nn.ReLU()
        self.pool1 = torch.nn.MaxPool2d(2, 2)

        self.conv2 = torch.nn.Conv2d(16, 32, 3, padding=1)
        self.bn2   = torch.nn.BatchNorm2d(32)
        self.act2  = torch.nn.ReLU()
        self.pool2 = torch.nn.MaxPool2d(2, 2)

        self.conv3 = torch.nn.Conv2d(32, 64, 3, padding=1)
        self.bn3   = torch.nn.BatchNorm2d(64)
        self.act3  = torch.nn.ReLU()
        self.pool3 = torch.nn.MaxPool2d(2, 2)

        self.fc1   = torch.nn.Linear(30 * 30 * 64, 256)
        self.act4  = torch.nn.ReLU()
        self.drop  = torch.nn.Dropout(0.5)

        self.fc2   = torch.nn.Linear(256, 3)

    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.act1(x)
        x = self.pool1(x)

        x = self.conv2(x)
        x = self.bn2(x)
        x = self.act2(x)
        x = self.pool2(x)

        x = self.conv3(x)
        x = self.bn3(x)
        x = self.act3(x)
        x = self.pool3(x)

        x = x.view(x.size(0), x.size(1) * x.size(2) * x.size(3))
        x = self.fc1(x)
        x = self.act4(x)
        x = self.drop(x)
        x = self.fc2(x)

        return x

# %%
# Переведем наш класс с параметрами в словарь

def class2dict(f):
  return dict((name, getattr(f, name)) for name in dir(f) if not name.startswith('__'))

# %%
# функция обучения
def train(model, device, train_loader, optimizer, criterion, epoch, WANDB):
    model.train()
    train_loss = 0
    correct = 0

    n_ex = len(train_loader)

    for batch_idx, (data, target) in tqdm(enumerate(train_loader), total=n_ex):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad() # обнуляем градиенты
        output = model(data)
        pred = output.argmax(dim=1, keepdim=True)
        correct += pred.eq(target.view_as(pred)).sum().item()
        train_loss = criterion(output, target) # считаем лосс
        train_loss.backward() # обратный проход
        optimizer.step() # делаем шаг оптимизатором

    tqdm.write('\nTrain set: Average loss: {:.4f}, Accuracy: {:.2f}%'.format(
        train_loss, 100. * correct / len(train_loader.dataset)))

    # логируем функцию потерь и точность
    if WANDB:
        wandb.log({'train_loss': train_loss,
                   'train_accuracy': correct / len(train_loader.dataset)})

# %%
# функция инференса
def test(model, device, test_loader, criterion, WANDB):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss = criterion(output, target)
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()

    tqdm.write('Test set: Average loss: {:.4f}, Accuracy: {:.2f}%'.format(
        test_loss, 100. * correct / len(test_loader.dataset)))

    if WANDB:
        wandb.log({'test_loss': test_loss,
                   'test_accuracy': correct / len(test_loader.dataset)})

# %%
def main_car(model):
    if CFG.wandb:
        os.environ["WANDB_API_KEY"] = CFG.api
        wandb.init(project=CFG.project, entity=CFG.entity, reinit=True, config=class2dict(CFG))

    seed_everything(CFG.seed)

    model = model.to(DEVICE)

    if CFG.wandb:
        wandb.watch(model, log='all')

    optimizer = optim.Adam(model.parameters(), lr=CFG.lr)

    criterion = nn.CrossEntropyLoss()

    for epoch in range(1, CFG.num_epochs + 1):
        print('\nEpoch:', epoch)
        train(model, DEVICE, dataloader['training'], optimizer, criterion, epoch, CFG.wandb)
        test(model, DEVICE, dataloader['validation'], criterion, CFG.wandb)
    print('Training is ended!')

    if CFG.wandb:
        model_name = type(model).__name__
        torch.save(model.state_dict(), 'model.pth')
        artifact = wandb.Artifact(name=model_name, type='model')
        artifact.add_file('model.pth')
        wandb.log_artifact(artifact)
        wandb.finish()

# %% [markdown]
# такс, тут, чтобы сохранять модели как артефакт, пригодилось довольно много статей: 1. https://docs.wandb.ai/models/ref/python/experiments 2.https://wandb.ai/wandb/common-ml-errors/reports/How-to-save-and-load-models-in-PyTorch--VmlldzozMjg0MTE 3.https://docs.wandb.ai/models/artifacts 4. https://docs.pytorch.org/docs/2.12/generated/torch.save.html 5. https://stackoverflow.com/questions/510972/getting-the-class-name-of-an-instance

# %%
model_CNN = CIFAR_Net()

# %%
main_car(model_CNN)
# Out:
# Epoch: 1
#   8%|▊         | 7/87 [00:02<00:22,  3.49it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_686/1918925836.py in <cell line: 0>()
# ----> 1 main_car(model_CNN)
#
# /tmp/ipykernel_686/1240562907.py in main_car(model)
#      17     for epoch in range(1, CFG.num_epochs + 1):
#      18         print('\nEpoch:', epoch)
# ---> 19         train(model, DEVICE, dataloader['training'], optimizer, criterion, epoch, CFG.wandb)
#      20         test(model, DEVICE, dataloader['validation'], criterion, CFG.wandb)
#      21     print('Training is ended!')
#
# /tmp/ipykernel_686/3552397100.py in train(model, device, train_loader, optimizer, criterion, epoch, WANDB)
#      14         correct += pred.eq(target.view_as(pred)).sum().item()
#      15         train_loss = criterion(output, target) # считаем лосс
# ---> 16         train_loss.backward() # обратный проход
#      17         optimizer.step() # делаем шаг оптимизатором
#      18
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     629                 inputs=inputs,
#     630             )
# --> 631         torch.autograd.backward(
#     632             self, gradient, retain_graph, create_graph, inputs=inputs
#     633         )
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     379     # some Python versions print out the first line of a multi-line function
#     380     # calls in the traceback and some print out the last line
# --> 381     _engine_run_backward(
#     382         tensors,
#     383         grad_tensors_,
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     867         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     868     try:
# --> 869         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     870             t_outputs, *args, **kwargs
#     871         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %% [markdown]
# такс наблюдаем што Accuracy скачет между эпохами, в целом 54 процента это конечно беда(хоть это и самая простая начальная модель). предполагаю, что все плачевно, потому что модель обучается с нуля на маленьком датасете, и этого недостаточно для стабильного обучения. вотс, попытаемся улучшить ситуацию используя функцию обучения из семинара 18-19, тама у нас StepLR scheduler и сохранение лучшей модели, а не последней эпохи

# %%
def train_model(model, criterion, optimizer, scheduler, epochs=10):
    losses = {'training': [], 'validation': []}
    accuracies = {'training': [], 'validation': []}
    best_model_weights = model.state_dict()
    best_accuracy = 0.
    progress = tqdm(range(epochs), desc='Epoch:')

    for epoch in progress:
        for phase in ['training', 'validation']:
            loss_accum = 0.
            corr_accum = 0
            model.train(mode=(phase == 'training'))

            for inputs, labels in tqdm(dataloader[phase], desc=f'Phase {phase}:'):
                inputs = inputs.to(DEVICE)
                labels = labels.to(DEVICE)

                if phase == 'training':
                    optimizer.zero_grad()
                    outp = model(inputs)
                    loss = criterion(outp, labels)
                    loss.backward()
                    optimizer.step()
                else:
                    with torch.no_grad():
                        outp = model(inputs)
                        loss = criterion(outp, labels)

                preds = torch.argmax(outp, -1)
                loss_accum += loss.item()
                corr_accum += (preds == labels.data).sum().item()

            if phase == 'training':
                scheduler.step()

            epoch_loss = loss_accum / len(dataloader[phase])
            epoch_accuracy = corr_accum / dataset_size[phase]
            losses[phase].append(epoch_loss)
            accuracies[phase].append(epoch_accuracy)
            progress.set_description('loss: {:.4f}, acc: {:.4f}'.format(epoch_loss, epoch_accuracy))

            if CFG.wandb:
                wandb.log({f'{phase}_loss': epoch_loss, f'{phase}_accuracy': epoch_accuracy})

            if phase == 'validation' and epoch_accuracy > best_accuracy:
                best_accuracy = epoch_accuracy
                best_model_weights = model.state_dict()

    model.load_state_dict(best_model_weights)
    return model, losses, accuracies

# %%
def main_car(model):
    if CFG.wandb:
        os.environ["WANDB_API_KEY"] = CFG.api
        wandb.init(project=CFG.project, entity=CFG.entity, reinit='finish_previous', config=class2dict(CFG))

    seed_everything(CFG.seed)

    model = model.to(DEVICE)

    optimizer = optim.Adam(model.parameters(), lr=CFG.lr)
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)
    criterion = nn.CrossEntropyLoss()

    model, losses, accuracies = train_model(model, criterion, optimizer, scheduler, CFG.num_epochs)

    print('Training is ended!')

    if CFG.wandb:
        model_name = type(model).__name__
        torch.save(model.state_dict(), 'model.pth')
        artifact = wandb.Artifact(name=model_name, type='model')
        artifact.add_file('model.pth')
        wandb.log_artifact(artifact)
        wandb.finish()

    return model, losses, accuracies

# %%
import torchvision.models as models

# %%
model_resnet = models.resnet18(weights=models.ResNet18_Weights.DEFAULT)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 127MB/s]

# %% [markdown]
# статьи, которые понадобились: 1. https://neurohive.io/ru/vidy-nejrosetej/resnet-34-50-101 2. https://docs.pytorch.org/vision/stable/models/generated/torchvision.models.resnet18.html 3. https://docs.exponenta.ru/deeplearning/ref/resnet18.html

# %%
for param in model_resnet.parameters():
    param.requires_grad = False

for name, param in model_resnet.layer4.named_parameters():
    param.requires_grad = True
    print(f'{name:50}{param.requires_grad}')

model_resnet.fc = torch.nn.Linear(512, 3)
model_resnet.to(DEVICE)

CFG.lr = 0.0001
loss = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_resnet.parameters(), lr=CFG.lr)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)
# Out:
# 0.conv1.weight                                    True
# 0.bn1.weight                                      True
# 0.bn1.bias                                        True
# 0.conv2.weight                                    True
# 0.bn2.weight                                      True
# 0.bn2.bias                                        True
# 0.downsample.0.weight                             True
# 0.downsample.1.weight                             True
# 0.downsample.1.bias                               True
# 1.conv1.weight                                    True
# 1.bn1.weight                                      True
# 1.bn1.bias                                        True
# 1.conv2.weight                                    True
# 1.bn2.weight                                      True
# 1.bn2.bias                                        True

# %%
model_resnet, losses_resnet, accuracies_resnet = main_car(model_resnet)
# Out:
# Epoch::   0%|          | 0/10 [00:00<?, ?it/s]
# Phase training::   0%|          | 0/87 [00:00<?, ?it/s]
# Phase training::   1%|          | 1/87 [00:00<00:26,  3.23it/s]
# Phase training::   5%|▍         | 4/87 [00:00<00:07, 10.50it/s]
# Phase training::   8%|▊         | 7/87 [00:00<00:05, 14.53it/s]
# Phase training::  11%|█▏        | 10/87 [00:00<00:04, 17.31it/s]
# Phase training::  14%|█▍        | 12/87 [00:00<00:04, 17.86it/s]
# Phase training::  16%|█▌        | 14/87 [00:00<00:04, 17.71it/s]
# Phase training::  18%|█▊        | 16/87 [00:01<00:03, 17.98it/s]
# Phase training::  21%|██        | 18/87 [00:01<00:03, 18.12it/s]
# Phase training::  23%|██▎       | 20/87 [00:01<00:03, 18.08it/s]
# Phase training::  25%|██▌       | 22/87 [00:01<00:03, 16.94it/s]
# Phase training::  28%|██▊       | 24/87 [00:01<00:03, 17.70it/s]
# Phase training::  31%|███       | 27/87 [00:01<00:03, 18.03it/s]
# Phase training::  34%|███▍      | 30/87 [00:01<00:02, 19.73it/s]
# Phase training::  38%|███▊      | 33/87 [00:01<00:02, 19.01it/s]
# Phase training::  40%|████      | 35/87 [00:02<00:02, 18.50it/s]
# Phase training::  44%|████▎     | 38/87 [00:02<00:02, 20.29it/s]
# Phase training::  47%|████▋     | 41/87 [00:02<00:02, 20.74it/s]
# Phase training::  51%|█████     | 44/87 [00:02<00:02, 20.58it/s]
# Phase training::  54%|█████▍    | 47/87 [00:02<00:01, 20.22it/s]
# Phase training::  57%|█████▋    | 50/87 [00:02<00:01, 20.72it/s]
# Phase training::  61%|██████    | 53/87 [00:02<00:01, 18.90it/s]
# Phase training::  63%|██████▎   | 55/87 [00:03<00:01, 16.97it/s]
# Phase training::  66%|██████▌   | 57/87 [00:03<00:01, 15.30it/s]
# Phase training::  68%|██████▊   | 59/87 [00:03<00:02, 13.45it/s]
# Phase training::  70%|███████   | 61/87 [00:03<00:02, 12.64it/s]
# Phase training::  72%|███████▏  | 63/87 [00:03<00:01, 12.40it/s]
# Phase training::  75%|███████▍  | 65/87 [00:04<00:01, 12.33it/s]
# Phase training::  77%|███████▋  | 67/87 [00:04<00:01, 12.35it/s]
# Phase training::  79%|███████▉  | 69/87 [00:04<00:01, 11.65it/s]
# Phase training::  82%|████████▏ | 71/87 [00:04<00:01, 11.55it/s]
# Phase training::  84%|████████▍ | 73/87 [00:04<00:01, 11.01it/s]
# Phase training::  86%|████████▌ | 75/87 [00:04<00:01, 11.92it/s]
# Phase training::  89%|████████▊ | 77/87 [00:05<00:00, 12.82it/s]
# Phase training::  91%|█████████ | 79/87 [00:05<00:00, 13.00it/s]
# Phase training::  93%|█████████▎| 81/87 [00:05<00:00, 12.08it/s]
# Phase training::  95%|█████████▌| 83/87 [00:05<00:00, 12.41it/s]
# Phase training::  98%|█████████▊| 85/87 [00:05<00:00, 13.88it/s]
# Phase training:: 100%|██████████| 87/87 [00:05<00:00, 15.15it/s]
# loss: 0.8474, acc: 0.6247:   0%|          | 0/10 [00:05<?, ?it/s]
# Phase validation::   0%|          | 0/8 [00:00<?, ?it/s]
# Phase validation::  12%|█▎        | 1/8 [00:00<00:02,  3.36it/s]
# Phase validation::  38%|███▊      | 3/8 [00:00<00:00,  6.81it/s]
# Phase validation::  62%|██████▎   | 5/8 [00:00<00:00,  7.86it/s]
# Phase validation:: 100%|██████████| 8/8 [00:00<00:00,  8.90it/s]
# loss: 0.7178, acc: 0.6734:  10%|█         | 1/10 [00:06<00:59,  6.66s/it]
# Phase training::   0%|          | 0/87 [00:00<?, ?it/s]
# Phase training::   1%|          | 1/87 [00:00<00:15,  5.55it/s]
# Phase training::   5%|▍         | 4/87 [00:00<00:05, 14.16it/s]
# Phase training::   7%|▋         | 6/87 [00:00<00:05, 15.37it/s]
# Phase training::   9%|▉         | 8/87 [00:00<00:04, 16.38it/s]
# Phase training::  11%|█▏        | 10/87 [00:00<00:04, 17.49it/s]
# Phase training::  14%|█▍        | 12/87 [00:00<00:04, 16.74it/s]
# Phase training::  16%|█▌        | 14/87 [00:00<00:04, 17.37it/s]
# Phase training::  20%|█▉        | 17/87 [00:01<00:03, 18.16it/s]
# Phase training::  22%|██▏       | 19/87 [00:01<00:03, 18.27it/s]
# Phase training::  24%|██▍       | 21/87 [00:01<00:03, 18.71it/s]
# Phase training::  28%|██▊       | 24/87 [00:01<00:03, 20.23it/s]
# Phase training::  31%|███       | 27/87 [00:01<00:02, 21.11it/s]
# Phase training::  34%|███▍      | 30/87 [00:01<00:02, 19.39it/s]
# Phase training::  38%|███▊      | 33/87 [00:01<00:02, 18.96it/s]
# Phase training::  40%|████      | 35/87 [00:01<00:02, 18.83it/s]
# Phase training::  44%|████▎     | 38/87 [00:02<00:02, 19.33it/s]
# Phase training::  46%|████▌     | 40/87 [00:02<00:02, 18.93it/s]
# Phase training::  48%|████▊     | 42/87 [00:02<00:02, 18.49it/s]
# Phase training::  52%|█████▏    | 45/87 [00:02<00:02, 20.28it/s]
# Phase training::  55%|█████▌    | 48/87 [00:02<00:01, 20.84it/s]
# Phase training::  59%|█████▊    | 51/87 [00:02<00:01, 19.74it/s]
# Phase training::  61%|██████    | 53/87 [00:02<00:01, 19.72it/s]
# Phase training::  64%|██████▍   | 56/87 [00:02<00:01, 20.27it/s]
# Phase training::  68%|██████▊   | 59/87 [00:03<00:01, 20.02it/s]
# Phase training::  71%|███████▏  | 62/87 [00:03<00:01, 19.64it/s]
# Phase training::  74%|███████▎  | 64/87 [00:03<00:01, 19.28it/s]
# Phase training::  76%|███████▌  | 66/87 [00:03<00:01, 19.22it/s]
# Phase training::  79%|███████▉  | 69/87 [00:03<00:00, 19.53it/s]
# Phase training::  83%|████████▎ | 72/87 [00:03<00:00, 19.26it/s]
# Phase training::  85%|████████▌ | 74/87 [00:03<00:00, 17.85it/s]
# Phase training::  87%|████████▋ | 76/87 [00:04<00:00, 17.74it/s]
# Phase training::  90%|████████▉ | 78/87 [00:04<00:00, 18.19it/s]
# Phase training::  93%|█████████▎| 81/87 [00:04<00:00, 20.01it/s]
# Phase training::  97%|█████████▋| 84/87 [00:04<00:00, 20.51it/s]
# Phase training:: 100%|██████████| 87/87 [00:04<00:00, 18.93it/s]
# loss: 0.5874, acc: 0.7614:  10%|█         | 1/10 [00:11<00:59,  6.66s/it]
# Phase validation::   0%|          | 0/8 [00:00<?, ?it/s]
# Phase validation::  12%|█▎        | 1/8 [00:00<00:01,  3.82it/s]
# Phase validation::  38%|███▊      | 3/8 [00:00<00:00,  6.52it/s]
# Phase validation::  62%|██████▎   | 5/8 [00:00<00:00,  7.95it/s]
# Phase validation:: 100%|██████████| 8/8 [00:00<00:00,  8.95it/s]
# loss: 0.6556, acc: 0.6653:  20%|██        | 2/10 [00:12<00:47,  5.98s/it]
# Phase training::   0%|          | 0/87 [00:00<?, ?it/s]
# Phase training::   1%|          | 1/87 [00:00<00:16,  5.22it/s]
# Phase training::   5%|▍         | 4/87 [00:00<00:06, 13.63it/s]
# Phase training::   8%|▊         | 7/87 [00:00<00:05, 15.94it/s]
# Phase training::  10%|█         | 9/87 [00:00<00:04, 15.80it/s]
# Phase training::  14%|█▍        | 12/87 [00:00<00:03, 18.88it/s]
# Phase training::  16%|█▌        | 14/87 [00:00<00:03, 18.93it/s]
# Phase training::  18%|█▊        | 16/87 [00:00<00:03, 18.60it/s]
# Phase training::  21%|██        | 18/87 [00:01<00:03, 17.80it/s]
# Phase training::  24%|██▍       | 21/87 [00:01<00:03, 18.09it/s]
# Phase training::  28%|██▊       | 24/87 [00:01<00:03, 19.35it/s]
# Phase training::  31%|███       | 27/87 [00:01<00:03, 17.99it/s]
# Phase training::  33%|███▎      | 29/87 [00:01<00:03, 16.81it/s]
# Phase training::  36%|███▌      | 31/87 [00:01<00:03, 16.85it/s]
# Phase training::  39%|███▉      | 34/87 [00:01<00:02, 18.48it/s]
# Phase training::  41%|████▏     | 36/87 [00:02<00:02, 18.80it/s]
# Phase training::  45%|████▍     | 39/87 [00:02<00:02, 18.90it/s]
# Phase training::  47%|████▋     | 41/87 [00:02<00:02, 18.45it/s]
# Phase training::  51%|█████     | 44/87 [00:02<00:02, 19.94it/s]
# Phase training::  53%|█████▎    | 46/87 [00:02<00:02, 19.79it/s]
# Phase training::  55%|█████▌    | 48/87 [00:02<00:02, 18.07it/s]
# Phase training::  57%|█████▋    | 50/87 [00:02<00:02, 17.49it/s]
# Phase training::  60%|█████▉    | 52/87 [00:02<00:01, 18.01it/s]
# Phase training::  62%|██████▏   | 54/87 [00:03<00:01, 18.45it/s]
# Phase training::  64%|██████▍   | 56/87 [00:03<00:01, 18.35it/s]
# Phase training::  67%|██████▋   | 58/87 [00:03<00:01, 18.59it/s]
# Phase training::  69%|██████▉   | 60/87 [00:03<00:01, 18.05it/s]
# Phase training::  71%|███████▏  | 62/87 [00:03<00:01, 17.04it/s]
# Phase training::  74%|███████▎  | 64/87 [00:03<00:01, 15.80it/s]
# Phase training::  76%|███████▌  | 66/87 [00:03<00:01, 14.70it/s]
# Phase training::  78%|███████▊  | 68/87 [00:03<00:01, 13.55it/s]
# Phase training::  80%|████████  | 70/87 [00:04<00:01, 12.57it/s]
# Phase training::  83%|████████▎ | 72/87 [00:04<00:01, 11.92it/s]
# Phase training::  85%|████████▌ | 74/87 [00:04<00:01, 11.20it/s]
# Phase training::  87%|████████▋ | 76/87 [00:04<00:00, 11.29it/s]
# Phase training::  90%|████████▉ | 78/87 [00:04<00:00, 10.92it/s]
# Phase training::  92%|█████████▏| 80/87 [00:05<00:00, 10.85it/s]
# Phase training::  94%|█████████▍| 82/87 [00:05<00:00, 11.01it/s]
# Phase training::  97%|█████████▋| 84/87 [00:05<00:00, 12.08it/s]
# Phase training:: 100%|██████████| 87/87 [00:05<00:00, 15.58it/s]
# loss: 0.4629, acc: 0.8192:  20%|██        | 2/10 [00:17<00:47,  5.98s/it]
# Phase validation::   0%|          | 0/8 [00:00<?, ?it/s]
# Phase validation::  12%|█▎        | 1/8 [00:00<00:02,  2.54it/s]
# Phase validation::  38%|███▊      | 3/8 [00:00<00:00,  5.39it/s]
# Phase validation::  62%|██████▎   | 5/8 [00:00<00:00,  7.15it/s]
# Phase validation:: 100%|██████████| 8/8 [00:01<00:00,  7.90it/s]
# loss: 0.7758, acc: 0.6815:  30%|███       | 3/10 [00:18<00:43,  6.27s/it]
# Phase training::   0%|          | 0/87 [00:00<?, ?it/s]
# Phase training::   1%|          | 1/87 [00:00<00:15,  5.68it/s]
# Phase training::   5%|▍         | 4/87 [00:00<00:05, 14.33it/s]
# Phase training::   7%|▋         | 6/87 [00:00<00:05, 15.18it/s]
# Phase training::   9%|▉         | 8/87 [00:00<00:04, 16.34it/s]
# Phase training::  13%|█▎        | 11/87 [00:00<00:04, 18.05it/s]
# Phase training::  15%|█▍        | 13/87 [00:00<00:04, 17.74it/s]
# Phase training::  17%|█▋        | 15/87 [00:00<00:04, 17.32it/s]
# Phase training::  20%|█▉        | 17/87 [00:01<00:03, 17.74it/s]
# Phase training::  22%|██▏       | 19/87 [00:01<00:03, 17.79it/s]
# Phase training::  24%|██▍       | 21/87 [00:01<00:03, 17.56it/s]
# Phase training::  26%|██▋       | 23/87 [00:01<00:03, 17.47it/s]
# Phase training::  29%|██▊       | 25/87 [00:01<00:03, 17.18it/s]
# Phase training::  31%|███       | 27/87 [00:01<00:03, 17.56it/s]
# Phase training::  34%|███▍      | 30/87 [00:01<00:02, 20.39it/s]
# Phase training::  38%|███▊      | 33/87 [00:01<00:02, 18.61it/s]
# Phase training::  40%|████      | 35/87 [00:02<00:02, 17.96it/s]
# Phase training::  44%|████▎     | 38/87 [00:02<00:02, 19.21it/s]
# Phase training::  47%|████▋     | 41/87 [00:02<00:02, 19.98it/s]
# Phase training::  51%|█████     | 44/87 [00:02<00:02, 18.89it/s]
# Phase training::  53%|█████▎    | 46/87 [00:02<00:02, 18.43it/s]
# Phase training::  56%|█████▋    | 49/87 [00:02<00:01, 19.61it/s]
# Phase training::  60%|█████▉    | 52/87 [00:02<00:01, 20.30it/s]
# Phase training::  63%|██████▎   | 55/87 [00:03<00:01, 19.71it/s]
# Phase training::  66%|██████▌   | 57/87 [00:03<00:01, 18.82it/s]
# Phase training::  69%|██████▉   | 60/87 [00:03<00:01, 19.81it/s]
# Phase training::  72%|███████▏  | 63/87 [00:03<00:01, 20.55it/s]
# Phase training::  76%|███████▌  | 66/87 [00:03<00:01, 19.79it/s]
# Phase training::  78%|███████▊  | 68/87 [00:03<00:00, 19.81it/s]
# Phase training::  80%|████████  | 70/87 [00:03<00:00, 18.88it/s]
# Phase training::  83%|████████▎ | 72/87 [00:03<00:00, 18.43it/s]
# Phase training::  85%|████████▌ | 74/87 [00:04<00:00, 18.35it/s]
# Phase training::  89%|████████▊ | 77/87 [00:04<00:00, 18.67it/s]
# Phase training::  92%|█████████▏| 80/87 [00:04<00:00, 19.62it/s]
# Phase training::  94%|█████████▍| 82/87 [00:04<00:00, 19.28it/s]
# Phase training:: 100%|██████████| 87/87 [00:04<00:00, 18.63it/s]
# loss: 0.3554, acc: 0.8727:  30%|███       | 3/10 [00:23<00:43,  6.27s/it]
# Phase validation::   0%|          | 0/8 [00:00<?, ?it/s]
# Phase validation::  12%|█▎        | 1/8 [00:00<00:01,  3.78it/s]
# Phase validation::  38%|███▊      | 3/8 [00:00<00:00,  7.72it/s]
# Phase validation::  62%|██████▎   | 5/8 [00:00<00:00,  8.45it/s]
# Phase validation:: 100%|██████████| 8/8 [00:00<00:00,  8.89it/s]
# loss: 0.9403, acc: 0.5927:  40%|████      | 4/10 [00:24<00:36,  6.00s/it]
# Phase training::   0%|          | 0/87 [00:00<?, ?it/s]
# Phase training::   1%|          | 1/87 [00:00<00:15,  5.51it/s]
# Phase training::   5%|▍         | 4/87 [00:00<00:06, 13.71it/s]
# Phase training::   7%|▋         | 6/87 [00:00<00:05, 14.91it/s]
# Phase training::  10%|█         | 9/87 [00:00<00:04, 18.15it/s]
# Phase training::  13%|█▎        | 11/87 [00:00<00:04, 18.30it/s]
# Phase training::  16%|█▌        | 14/87 [00:00<00:03, 19.10it/s]
# Phase training::  18%|█▊        | 16/87 [00:00<00:03, 18.74it/s]
# Phase training::  21%|██        | 18/87 [00:01<00:03, 17.99it/s]
# Phase training::  23%|██▎       | 20/87 [00:01<00:03, 17.69it/s]
# Phase training::  25%|██▌       | 22/87 [00:01<00:03, 17.43it/s]
# Phase training::  29%|██▊       | 25/87 [00:01<00:03, 19.20it/s]
# Phase training::  31%|███       | 27/87 [00:01<00:03, 18.81it/s]
# Phase training::  34%|███▍      | 30/87 [00:01<00:02, 19.54it/s]
# Phase training::  38%|███▊      | 33/87 [00:01<00:02, 19.66it/s]
# Phase training::  40%|████      | 35/87 [00:01<00:02, 18.61it/s]
# Phase training::  43%|████▎     | 37/87 [00:02<00:02, 17.58it/s]
# Phase training::  45%|████▍     | 39/87 [00:02<00:02, 17.74it/s]
# Phase training::  48%|████▊     | 42/87 [00:02<00:02, 19.42it/s]
# Phase training::  51%|█████     | 44/87 [00:02<00:02, 18.85it/s]
# Phase training::  53%|█████▎    | 46/87 [00:02<00:02, 19.05it/s]
# Phase training::  55%|█████▌    | 48/87 [00:02<00:02, 18.66it/s]
# Phase training::  59%|█████▊    | 51/87 [00:02<00:01, 19.87it/s]
# Phase training::  61%|██████    | 53/87 [00:02<00:01, 18.61it/s]
# Phase training::  63%|██████▎   | 55/87 [00:03<00:01, 18.06it/s]
# Phase training::  66%|██████▌   | 57/87 [00:03<00:01, 17.34it/s]
# Phase training::  68%|██████▊   | 59/87 [00:03<00:01, 17.48it/s]
# Phase training::  71%|███████▏  | 62/87 [00:03<00:01, 18.97it/s]
# Phase training::  75%|███████▍  | 65/87 [00:03<00:01, 19.94it/s]
# Phase training::  77%|███████▋  | 67/87 [00:03<00:01, 19.56it/s]
# Phase training::  79%|███████▉  | 69/87 [00:03<00:01, 16.38it/s]
# Phase training::  82%|████████▏ | 71/87 [00:04<00:01, 14.96it/s]
# Phase training::  84%|████████▍ | 73/87 [00:04<00:00, 14.29it/s]
# Phase training::  86%|████████▌ | 75/87 [00:04<00:00, 13.13it/s]
# Phase training::  89%|████████▊ | 77/87 [00:04<00:00, 12.45it/s]
# Phase training::  91%|█████████ | 79/87 [00:04<00:00, 11.94it/s]
# Phase training::  93%|█████████▎| 81/87 [00:04<00:00, 11.83it/s]
# Phase training::  95%|█████████▌| 83/87 [00:05<00:00, 11.81it/s]
# Phase training:: 100%|██████████| 87/87 [00:05<00:00, 16.33it/s]
# loss: 0.2464, acc: 0.9103:  40%|████      | 4/10 [00:29<00:36,  6.00s/it]
# Phase validation::   0%|          | 0/8 [00:00<?, ?it/s]
# Phase validation::  12%|█▎        | 1/8 [00:00<00:02,  2.92it/s]
# Phase validation::  38%|███▊      | 3/8 [00:00<00:00,  5.61it/s]
# Phase validation::  50%|█████     | 4/8 [00:00<00:00,  5.95it/s]
# Phase validation::  62%|██████▎   | 5/8 [00:00<00:00,  6.67it/s]
# Phase validation::  75%|███████▌  | 6/8 [00:00<00:00,  6.78it/s]
# Phase validation:: 100%|██████████| 8/8 [00:01<00:00,  6.63it/s]
# loss: 0.8333, acc: 0.6734:  50%|█████     | 5/10 [00:30<00:31,  6.20s/it]
# Phase training::   0%|          | 0/87 [00:00<?, ?it/s]
# Phase training::   1%|          | 1/87 [00:00<00:15,  5.50it/s]
# Phase training::   3%|▎         | 3/87 [00:00<00:07, 11.51it/s]
# Phase training::   6%|▌         | 5/87 [00:00<00:05, 14.56it/s]
# Phase training::   9%|▉         | 8/87 [00:00<00:04, 16.76it/s]
# Phase training::  13%|█▎        | 11/87 [00:00<00:04, 17.69it/s]
# Phase training::  15%|█▍        | 13/87 [00:00<00:04, 17.60it/s]
# Phase training::  17%|█▋        | 15/87 [00:00<00:04, 17.05it/s]
# Phase training::  20%|█▉        | 17/87 [00:01<00:03, 17.56it/s]
# Phase training::  23%|██▎       | 20/87 [00:01<00:03, 19.70it/s]
# Phase training::  26%|██▋       | 23/87 [00:01<00:03, 20.63it/s]
# Phase training::  30%|██▉       | 26/87 [00:01<00:02, 20.46it/s]
# Phase training::  33%|███▎      | 29/87 [00:01<00:02, 19.83it/s]
# Phase training::  36%|███▌      | 31/87 [00:01<00:02, 18.98it/s]
# Phase training::  39%|███▉      | 34/87 [00:01<00:02, 19.99it/s]
# Phase training::  41%|████▏     | 36/87 [00:01<00:02, 19.58it/s]
# Phase training::  44%|████▎     | 38/87 [00:02<00:02, 19.32it/s]
# Phase training::  47%|████▋     | 41/87 [00:02<00:02, 19.73it/s]
# Phase training::  49%|████▉     | 43/87 [00:02<00:02, 19.38it/s]
# Phase training::  52%|█████▏    | 45/87 [00:02<00:02, 18.95it/s]
# Phase training::  54%|█████▍    | 47/87 [00:02<00:02, 18.46it/s]
# Phase training::  56%|█████▋    | 49/87 [00:02<00:02, 18.18it/s]
# Phase training::  59%|█████▊    | 51/87 [00:02<00:02, 17.12it/s]
# Phase training::  62%|██████▏   | 54/87 [00:02<00:01, 17.28it/s]
# Phase training::  64%|██████▍   | 56/87 [00:03<00:01, 17.35it/s]
# Phase training::  67%|██████▋   | 58/87 [00:03<00:01, 17.30it/s]
# Phase training::  69%|██████▉   | 60/87 [00:03<00:01, 17.69it/s]
# Phase training::  72%|███████▏  | 63/87 [00:03<00:01, 19.68it/s]
# Phase training::  75%|███████▍  | 65/87 [00:03<00:01, 19.08it/s]
# Phase training::  78%|███████▊  | 68/87 [00:03<00:00, 20.17it/s]
# Phase training::  82%|████████▏ | 71/87 [00:03<00:00, 19.99it/s]
# Phase training::  85%|████████▌ | 74/87 [00:03<00:00, 20.68it/s]
# Phase training::  89%|████████▊ | 77/87 [00:04<00:00, 18.57it/s]
# Phase training::  91%|█████████ | 79/87 [00:04<00:00, 18.05it/s]
# Phase training::  93%|█████████▎| 81/87 [00:04<00:00, 18.33it/s]
# Phase training::  97%|█████████▋| 84/87 [00:04<00:00, 19.70it/s]
# Phase training:: 100%|██████████| 87/87 [00:04<00:00, 18.56it/s]
# loss: 0.1844, acc: 0.9487:  50%|█████     | 5/10 [00:35<00:31,  6.20s/it]
# Phase validation::   0%|          | 0/8 [00:00<?, ?it/s]
# Phase validation::  12%|█▎        | 1/8 [00:00<00:01,  3.79it/s]
# Phase validation::  38%|███▊      | 3/8 [00:00<00:00,  6.43it/s]
# Phase validation::  62%|██████▎   | 5/8 [00:00<00:00,  7.88it/s]
# Phase validation:: 100%|██████████| 8/8 [00:00<00:00,  8.99it/s]
# loss: 0.8977, acc: 0.6371:  60%|██████    | 6/10 [00:36<00:23,  5.99s/it]
# Phase training::   0%|          | 0/87 [00:00<?, ?it/s]
# Phase training::   1%|          | 1/87 [00:00<00:16,  5.37it/s]
# Phase training::   3%|▎         | 3/87 [00:00<00:07, 10.93it/s]
# Phase training::   6%|▌         | 5/87 [00:00<00:06, 13.60it/s]
# Phase training::   9%|▉         | 8/87 [00:00<00:04, 17.28it/s]
# Phase training::  11%|█▏        | 10/87 [00:00<00:04, 17.85it/s]
# Phase training::  14%|█▍        | 12/87 [00:00<00:04, 17.82it/s]
# Phase training::  16%|█▌        | 14/87 [00:00<00:04, 17.24it/s]
# Phase training::  18%|█▊        | 16/87 [00:01<00:04, 17.28it/s]
# Phase training::  21%|██        | 18/87 [00:01<00:03, 17.92it/s]
# Phase training::  24%|██▍       | 21/87 [00:01<00:03, 19.76it/s]
# Phase training::  26%|██▋       | 23/87 [00:01<00:03, 19.26it/s]
# Phase training::  30%|██▉       | 26/87 [00:01<00:03, 19.92it/s]
# Phase training::  32%|███▏      | 28/87 [00:01<00:03, 18.53it/s]
# Phase training::  36%|███▌      | 31/87 [00:01<00:02, 19.94it/s]
# Phase training::  39%|███▉      | 34/87 [00:01<00:02, 19.43it/s]
# Phase training::  41%|████▏     | 36/87 [00:02<00:02, 19.01it/s]
# Phase training::  44%|████▎     | 38/87 [00:02<00:02, 18.30it/s]
# Phase training::  46%|████▌     | 40/87 [00:02<00:02, 18.28it/s]
# Phase training::  48%|████▊     | 42/87 [00:02<00:02, 18.21it/s]
# Phase training::  51%|█████     | 44/87 [00:02<00:02, 18.33it/s]
# Phase training::  54%|█████▍    | 47/87 [00:02<00:01, 20.61it/s]
# Phase training::  57%|█████▋    | 50/87 [00:02<00:02, 18.18it/s]
# Phase training::  61%|██████    | 53/87 [00:02<00:01, 20.29it/s]
# Phase training::  64%|██████▍   | 56/87 [00:03<00:01, 18.22it/s]
# Phase training::  67%|██████▋   | 58/87 [00:03<00:01, 18.23it/s]
# Phase training::  70%|███████   | 61/87 [00:03<00:01, 19.70it/s]
# Phase training::  74%|███████▎  | 64/87 [00:03<00:01, 20.39it/s]
# Phase training::  77%|███████▋  | 67/87 [00:03<00:01, 19.91it/s]
# Phase training::  80%|████████  | 70/87 [00:03<00:00, 19.52it/s]
# Phase training::  83%|████████▎ | 72/87 [00:03<00:00, 18.39it/s]
# Phase training::  85%|████████▌ | 74/87 [00:04<00:00, 17.93it/s]
# Phase training::  87%|████████▋ | 76/87 [00:04<00:00, 18.25it/s]
# Phase training::  90%|████████▉ | 78/87 [00:04<00:00, 18.38it/s]
# Phase training::  93%|█████████▎| 81/87 [00:04<00:00, 17.86it/s]
# Phase training::  95%|█████████▌| 83/87 [00:04<00:00, 16.99it/s]
# Phase training:: 100%|██████████| 87/87 [00:04<00:00, 18.07it/s]
# loss: 0.1490, acc: 0.9537:  60%|██████    | 6/10 [00:41<00:23,  5.99s/it]
# Phase validation::   0%|          | 0/8 [00:00<?, ?it/s]
# Phase validation::  12%|█▎        | 1/8 [00:00<00:02,  2.55it/s]
# Phase validation::  38%|███▊      | 3/8 [00:00<00:01,  4.08it/s]
# Phase validation::  62%|██████▎   | 5/8 [00:01<00:00,  4.99it/s]
# Phase validation:: 100%|██████████| 8/8 [00:01<00:00,  5.83it/s]
# loss: 0.9417, acc: 0.6331:  70%|███████   | 7/10 [00:42<00:18,  6.06s/it]
# Phase training::   0%|          | 0/87 [00:00<?, ?it/s]
# Phase training::   1%|          | 1/87 [00:00<00:20,  4.10it/s]
# Phase training::   3%|▎         | 3/87 [00:00<00:10,  8.11it/s]
# Phase training::   6%|▌         | 5/87 [00:00<00:07, 10.47it/s]
# Phase training::   8%|▊         | 7/87 [00:00<00:06, 12.06it/s]
# Phase training::  10%|█         | 9/87 [00:00<00:06, 12.03it/s]
# Phase training::  13%|█▎        | 11/87 [00:00<00:05, 13.22it/s]
# Phase training::  15%|█▍        | 13/87 [00:01<00:05, 14.65it/s]
# Phase training::  17%|█▋        | 15/87 [00:01<00:04, 15.06it/s]
# Phase training::  20%|█▉        | 17/87 [00:01<00:04, 15.38it/s]
# Phase training::  22%|██▏       | 19/87 [00:01<00:04, 14.83it/s]
# Phase training::  24%|██▍       | 21/87 [00:01<00:04, 15.90it/s]
# Phase training::  26%|██▋       | 23/87 [00:01<00:04, 15.70it/s]
# Phase training::  30%|██▉       | 26/87 [00:01<00:03, 16.74it/s]
# Phase training::  33%|███▎      | 29/87 [00:01<00:03, 18.79it/s]
# Phase training::  36%|███▌      | 31/87 [00:02<00:02, 18.72it/s]
# Phase training::  38%|███▊      | 33/87 [00:02<00:02, 18.10it/s]
# Phase training::  40%|████      | 35/87 [00:02<00:02, 17.75it/s]
# Phase training::  44%|████▎     | 38/87 [00:02<00:02, 19.05it/s]
# Phase training::  46%|████▌     | 40/87 [00:02<00:02, 19.16it/s]
# Phase training::  48%|████▊     | 42/87 [00:02<00:02, 18.90it/s]
# Phase training::  51%|█████     | 44/87 [00:02<00:02, 17.96it/s]
# Phase training::  53%|█████▎    | 46/87 [00:02<00:02, 16.90it/s]
# Phase training::  55%|█████▌    | 48/87 [00:03<00:02, 17.09it/s]
# Phase training::  59%|█████▊    | 51/87 [00:03<00:01, 18.76it/s]
# Phase training::  61%|██████    | 53/87 [00:03<00:01, 18.28it/s]
# Phase training::  64%|██████▍   | 56/87 [00:03<00:01, 19.61it/s]
# Phase training::  67%|██████▋   | 58/87 [00:03<00:01, 18.94it/s]
# Phase training::  69%|██████▉   | 60/87 [00:03<00:01, 18.45it/s]
# Phase training::  71%|███████▏  | 62/87 [00:03<00:01, 18.82it/s]
# Phase training::  74%|███████▎  | 64/87 [00:03<00:01, 17.87it/s]
# Phase training::  76%|███████▌  | 66/87 [00:04<00:01, 17.41it/s]
# Phase training::  78%|███████▊  | 68/87 [00:04<00:01, 18.00it/s]
# Phase training::  82%|████████▏ | 71/87 [00:04<00:00, 19.67it/s]
# Phase training::  84%|████████▍ | 73/87 [00:04<00:00, 19.00it/s]
# Phase training::  86%|████████▌ | 75/87 [00:04<00:00, 18.15it/s]
# Phase training::  90%|████████▉ | 78/87 [00:04<00:00, 20.08it/s]
# Phase training::  93%|█████████▎| 81/87 [00:04<00:00, 20.11it/s]
# Phase training::  97%|█████████▋| 84/87 [00:04<00:00, 18.81it/s]
# Phase training:: 100%|██████████| 87/87 [00:05<00:00, 17.11it/s]
# loss: 0.1308, acc: 0.9595:  70%|███████   | 7/10 [00:47<00:18,  6.06s/it]
# Phase validation::   0%|          | 0/8 [00:00<?, ?it/s]
# Phase validation::  12%|█▎        | 1/8 [00:00<00:01,  3.74it/s]
# Phase validation::  38%|███▊      | 3/8 [00:00<00:00,  6.82it/s]
# Phase validation::  62%|██████▎   | 5/8 [00:00<00:00,  8.20it/s]
# Phase validation:: 100%|██████████| 8/8 [00:00<00:00,  9.17it/s]
# loss: 0.9820, acc: 0.6371:  80%|████████  | 8/10 [00:48<00:12,  6.04s/it]
# Phase training::   0%|          | 0/87 [00:00<?, ?it/s]
# Phase training::   1%|          | 1/87 [00:00<00:15,  5.42it/s]
# Phase training::   5%|▍         | 4/87 [00:00<00:05, 13.91it/s]
# Phase training::   7%|▋         | 6/87 [00:00<00:05, 15.50it/s]
# Phase training::   9%|▉         | 8/87 [00:00<00:05, 15.45it/s]
# Phase training::  13%|█▎        | 11/87 [00:00<00:04, 17.96it/s]
# Phase training::  16%|█▌        | 14/87 [00:00<00:03, 19.13it/s]
# Phase training::  18%|█▊        | 16/87 [00:00<00:03, 18.58it/s]
# Phase training::  21%|██        | 18/87 [00:01<00:03, 17.76it/s]
# Phase training::  23%|██▎       | 20/87 [00:01<00:03, 17.32it/s]
# Phase training::  25%|██▌       | 22/87 [00:01<00:03, 17.27it/s]
# Phase training::  29%|██▊       | 25/87 [00:01<00:03, 18.08it/s]
# Phase training::  31%|███       | 27/87 [00:01<00:03, 17.69it/s]
# Phase training::  34%|███▍      | 30/87 [00:01<00:02, 19.50it/s]
# Phase training::  38%|███▊      | 33/87 [00:01<00:02, 20.36it/s]
# Phase training::  41%|████▏     | 36/87 [00:02<00:02, 19.48it/s]
# Phase training::  44%|████▎     | 38/87 [00:02<00:02, 17.34it/s]
# Phase training::  47%|████▋     | 41/87 [00:02<00:02, 18.62it/s]
# Phase training::  49%|████▉     | 43/87 [00:02<00:02, 18.78it/s]
# Phase training::  52%|█████▏    | 45/87 [00:02<00:02, 18.62it/s]
# Phase training::  54%|█████▍    | 47/87 [00:02<00:02, 17.83it/s]
# Phase training::  57%|█████▋    | 50/87 [00:02<00:01, 19.27it/s]
# Phase training::  61%|██████    | 53/87 [00:02<00:01, 20.30it/s]
# Phase training::  64%|██████▍   | 56/87 [00:03<00:01, 19.98it/s]
# Phase training::  67%|██████▋   | 58/87 [00:03<00:01, 19.05it/s]
# Phase training::  69%|██████▉   | 60/87 [00:03<00:01, 18.52it/s]
# Phase training::  71%|███████▏  | 62/87 [00:03<00:01, 18.84it/s]
# Phase training::  75%|███████▍  | 65/87 [00:03<00:01, 19.07it/s]
# Phase training::  77%|███████▋  | 67/87 [00:03<00:01, 18.45it/s]
# Phase training::  79%|███████▉  | 69/87 [00:03<00:00, 18.22it/s]
# Phase training::  82%|████████▏ | 71/87 [00:03<00:00, 17.99it/s]
# Phase training::  84%|████████▍ | 73/87 [00:04<00:00, 18.46it/s]
# Phase training::  87%|████████▋ | 76/87 [00:04<00:00, 19.63it/s]
# Phase training::  90%|████████▉ | 78/87 [00:04<00:00, 18.68it/s]
# Phase training::  92%|█████████▏| 80/87 [00:04<00:00, 18.19it/s]
# Phase training::  95%|█████████▌| 83/87 [00:04<00:00, 19.69it/s]
# Phase training:: 100%|██████████| 87/87 [00:04<00:00, 18.49it/s]
# loss: 0.1180, acc: 0.9653:  80%|████████  | 8/10 [00:53<00:12,  6.04s/it]
# Phase validation::   0%|          | 0/8 [00:00<?, ?it/s]
# Phase validation::  12%|█▎        | 1/8 [00:00<00:01,  3.72it/s]
# Phase validation::  38%|███▊      | 3/8 [00:00<00:00,  5.69it/s]
# Phase validation::  62%|██████▎   | 5/8 [00:00<00:00,  6.72it/s]
# Phase validation:: 100%|██████████| 8/8 [00:01<00:00,  7.22it/s]
# loss: 0.9069, acc: 0.6371:  90%|█████████ | 9/10 [00:54<00:05,  5.97s/it]
# Phase training::   0%|          | 0/87 [00:00<?, ?it/s]
# Phase training::   1%|          | 1/87 [00:00<00:26,  3.23it/s]
# Phase training::   3%|▎         | 3/87 [00:00<00:10,  7.82it/s]
# Phase training::   6%|▌         | 5/87 [00:00<00:07, 10.64it/s]
# Phase training::   8%|▊         | 7/87 [00:00<00:08,  9.92it/s]
# Phase training::  10%|█         | 9/87 [00:00<00:07,  9.88it/s]
# Phase training::  13%|█▎        | 11/87 [00:01<00:07, 10.40it/s]
# Phase training::  15%|█▍        | 13/87 [00:01<00:06, 11.02it/s]
# Phase training::  17%|█▋        | 15/87 [00:01<00:06, 11.41it/s]
# Phase training::  20%|█▉        | 17/87 [00:01<00:05, 12.08it/s]
# Phase training::  22%|██▏       | 19/87 [00:01<00:05, 12.46it/s]
# Phase training::  24%|██▍       | 21/87 [00:01<00:05, 12.87it/s]
# Phase training::  26%|██▋       | 23/87 [00:02<00:04, 12.80it/s]
# Phase training::  29%|██▊       | 25/87 [00:02<00:04, 13.60it/s]
# Phase training::  32%|███▏      | 28/87 [00:02<00:03, 15.38it/s]
# Phase training::  34%|███▍      | 30/87 [00:02<00:03, 16.29it/s]
# Phase training::  37%|███▋      | 32/87 [00:02<00:03, 17.07it/s]
# Phase training::  40%|████      | 35/87 [00:02<00:02, 18.80it/s]
# Phase training::  43%|████▎     | 37/87 [00:02<00:02, 18.25it/s]
# Phase training::  45%|████▍     | 39/87 [00:02<00:02, 17.48it/s]
# Phase training::  47%|████▋     | 41/87 [00:03<00:02, 18.02it/s]
# Phase training::  49%|████▉     | 43/87 [00:03<00:02, 18.05it/s]
# Phase training::  52%|█████▏    | 45/87 [00:03<00:02, 17.83it/s]
# Phase training::  55%|█████▌    | 48/87 [00:03<00:02, 19.18it/s]
# Phase training::  59%|█████▊    | 51/87 [00:03<00:01, 19.96it/s]
# Phase training::  61%|██████    | 53/87 [00:03<00:01, 19.44it/s]
# Phase training::  63%|██████▎   | 55/87 [00:03<00:01, 19.48it/s]
# Phase training::  66%|██████▌   | 57/87 [00:03<00:01, 19.19it/s]
# Phase training::  68%|██████▊   | 59/87 [00:03<00:01, 18.95it/s]
# Phase training::  70%|███████   | 61/87 [00:04<00:01, 18.49it/s]
# Phase training::  72%|███████▏  | 63/87 [00:04<00:01, 18.17it/s]
# Phase training::  76%|███████▌  | 66/87 [00:04<00:01, 19.06it/s]
# Phase training::  78%|███████▊  | 68/87 [00:04<00:01, 18.93it/s]
# Phase training::  82%|████████▏ | 71/87 [00:04<00:00, 19.81it/s]
# Phase training::  84%|████████▍ | 73/87 [00:04<00:00, 19.38it/s]
# Phase training::  86%|████████▌ | 75/87 [00:04<00:00, 19.14it/s]
# Phase training::  89%|████████▊ | 77/87 [00:04<00:00, 18.48it/s]
# Phase training::  91%|█████████ | 79/87 [00:05<00:00, 18.72it/s]
# Phase training::  93%|█████████▎| 81/87 [00:05<00:00, 18.24it/s]
# Phase training::  95%|█████████▌| 83/87 [00:05<00:00, 17.93it/s]
# Phase training:: 100%|██████████| 87/87 [00:05<00:00, 15.99it/s]
# loss: 0.0961, acc: 0.9769:  90%|█████████ | 9/10 [00:59<00:05,  5.97s/it]
# Phase validation::   0%|          | 0/8 [00:00<?, ?it/s]
# Phase validation::  12%|█▎        | 1/8 [00:00<00:01,  3.72it/s]
# Phase validation::  38%|███▊      | 3/8 [00:00<00:00,  6.46it/s]
# Phase validation::  62%|██████▎   | 5/8 [00:00<00:00,  8.01it/s]
# Phase validation:: 100%|██████████| 8/8 [00:00<00:00,  8.96it/s]
# loss: 0.9925, acc: 0.6411: 100%|██████████| 10/10 [01:00<00:00,  6.09s/it]
# Training is ended!
